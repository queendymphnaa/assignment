# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# MY JUPITER NOOTEBOOK ON IBM WATSON STUDIO

# %% [markdown]
# AGBODIKE DYMPHNA
# ENVIRONMENTAL HEALTH OFFICER

# %% [markdown]
# I am interested in data science because it helps me as an EHO it has a key role to play in climate change

# %% [markdown]
# Cell 5 will show you my calculations

# %%
(50/25)*5

# %% [markdown]
# USING BLOCKED QUOTES I CAN MAKE A NUMBERED LIST OF MY CELLS
# 1.Cell one the tittle
# 2.Cell two introduction
# 3.Cell 3 interest in data science
# BULLET LIST
# * CELL 1
# TITTLE
# * CELL 2
# INTRODUCTION

# %% [markdown]
# #### Add your code below following the instructions given in the course
